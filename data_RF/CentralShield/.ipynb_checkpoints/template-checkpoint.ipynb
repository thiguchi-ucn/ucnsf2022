# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os
from glob import glob

# %%
os.listdir('./211219_dipoles_SF_reverse/results/XA_0.5_YA_6.5_LA_1.5_LB_5_LC_1_TZ_5_I_200/')
# Out:
# ['map_X_150mm.png',
#  'line_x.table',
#  'line_x_y4cm25.table',
#  'line_x_z4cm25_wide.table',
#  'map_Y_425mm.png',
#  'map_Y_0mm.png',
#  'line_x_y4cm25_wide.table',
#  'line_x_z4cm25.table',
#  'line_x_yz3cm05_wide.table',
#  'line_x_yz3cm05.table',
#  'Graph.png',
#  'map_Z_0mm.png',
#  'line_x_wide.table',
#  'map_X_225mm.png',
#  'Thumbs.db',
#  'Graph_wide.png']

# %%
os.listdir('./')
# Out:
# ['.ipynb_checkpoints',
#  '211205_SF_loop_400',
#  '211206_SF_loop_310',
#  '211219_dipoles_SF_reverse',
#  'Original .ipynb',
#  'template.ipynb']

# %%
directory = r'N:\ParticlePhysics\UCN\_Users\dgeorgescu\SF_optimization\211206_SF_loop_310\results'

THETA_LIST = [10, 20, 30, 40, 50]  
INTERSECTX_LIST = []


for p in range (1,6):
    num = str(p*10) + "_I_150"

    for filename in os.listdir(directory):
        
        if filename.startswith("LC2X_10_THETAZ_") & filename.endswith(num):
            print (filename)
            
            targetdir = filename
            df_DC_center = pd.read_csv('211206_SF_loop_310/results/%s/line_x.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)
            df_DC_shiftZ = pd.read_csv('211206_SF_loop_310/results/%s/line_x_z4cm25.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)
            df_DC_shiftY = pd.read_csv('211206_SF_loop_310/results/%s/line_x_y4cm25.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)

            plt.plot(df_DC_center['X'], df_DC_center['BY'], label='y=z=0')
            #plt.plot(df_DC_shiftZ['X'], df_DC_shiftZ['BY'], label='y=0, z=42.5mm')
            plt.plot(df_DC_shiftY['X'], df_DC_shiftY['BY'], label='y=42.5mm, z=0')
            plt.legend()

            diff_list = []

            for i in range (1000, 1300):
                diff = abs(df_DC_center['BY'][i] - df_DC_shiftY['BY'][i])  
                diff_list.append(diff)
        
            minimum = np.min(diff_list)
            print (minimum)

            value = diff_list.index(minimum)
            print (df_DC_center['X'][value+1000])
            
            INTERSECTX_LIST.append(df_DC_center['X'][value+1000])
                        
        else:
            continue
# Out:
# LC2X_10_THETAZ_10_I_150
# 0.0021130612300002127
# 6.3
# LC2X_10_THETAZ_20_I_150
# 0.00020010818999960378
# 8.4
# LC2X_10_THETAZ_30_I_150
# 0.001201473810000131
# 9.65
# LC2X_10_THETAZ_40_I_150
# 0.0030114230200002368
# 10.4
# LC2X_10_THETAZ_50_I_150
# 0.0017307042299998798
# 11.0

# %%
print (THETA_LIST)
print (INTERSECTX_LIST)

plt.plot(THETA_LIST, INTERSECTX_LIST)
# Out:
# [10, 20, 30, 40, 50]
# [6.3, 8.4, 9.65, 10.4, 11.0]

# %%
targetdir = 'LC2X_4_THETAZ_50_I_150'
df_DC_center = pd.read_csv('211206_SF_loop_310/results/%s/line_x.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)
df_DC_shiftZ = pd.read_csv('211206_SF_loop_310/results/%s/line_x_z4cm25.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)
df_DC_shiftY = pd.read_csv('211206_SF_loop_310/results/%s/line_x_y4cm25.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)

plt.plot(df_DC_center['X'], df_DC_center['BY'], label='y=z=0')
plt.plot(df_DC_shiftZ['X'], df_DC_shiftZ['BY'], label='y=0, z=42.5mm')
plt.plot(df_DC_shiftY['X'], df_DC_shiftY['BY'], label='y=42.5mm, z=0')
plt.legend()

diff_list = []

for i in range (1000, 1300):
    diff = abs(df_DC_center['BY'][i] - df_DC_shiftZ['BY'][i])  
    diff_list.append(diff)
        
minimum = np.min(diff_list)
print (minimum)

value = diff_list.index(minimum)
print (df_DC_center['X'][value+1000])
# Out:
# 0.0009051230799999033
# 4.15

# %%
#df_DC_shiftY[(df_DC_shiftY.X > 0) & (df_DC_shiftY.X < 15.5)]['X']

# %%
targetdir = 'X_5_5_30_60_90_100_Y1_65_T1_30_T2_0_I_300'
df_DC_center = pd.read_csv('211221_dipoles_SF_rev_steps/results/%s/line_x.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)
df_DC_shiftZ = pd.read_csv('211221_dipoles_SF_rev_steps/results/%s/line_x_z4cm25.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)
df_DC_shiftY = pd.read_csv('211221_dipoles_SF_rev_steps/results/%s/line_x_y4cm25.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)

plt.plot(df_DC_center['X'], df_DC_center['BY'], label='y=z=0')
#plt.plot(df_DC_shiftZ['X'], df_DC_shiftZ['BY'], label='y=0, z=42.5mm')
plt.plot(df_DC_shiftY['X'], df_DC_shiftY['BY'], label='y=42.5mm, z=0')
plt.legend()

diff_list = []

for i in range (1100, 1400):
    diff = abs(df_DC_center['BY'][i] - df_DC_shiftY['BY'][i])  
    diff_list.append(diff)
        
minimum = np.min(diff_list)
print (minimum)

value = diff_list.index(minimum)
print (df_DC_center['X'][value+1100])

ByIntersect = df_DC_center['BY'][value]
#df_DC_center[df_DC_center.X > -6.1]['X']
# Out:
# 0.004937206099999258
# 5.9

# %% [markdown]
# df_DC_center[hihihih

# %%
directory = r'M:\ParticlePhysics\UCN\_Users\dgeorgescu\SF_optimization\211221_dipoles_SF_rev_steps\results'

anglz = []
crosses = []
sepy = []

for p in range (1,11):
    num = str(p*5) + "_T2_0_I_300"
    
    for filename in os.listdir(directory):
        
        if filename.startswith("X_5_5_30_60_90_100_Y1_65_T1_") & filename.endswith(num):
            print (filename)
            anglz.append(p*5)
            
            targetdir = filename
            df_DC_center = pd.read_csv('211221_dipoles_SF_rev_steps/results/%s/line_x.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)
            #df_DC_shiftZ = pd.read_csv('211219_dipoles_SF_reverse/results/%s/line_x_z4cm25.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)
            df_DC_shiftY = pd.read_csv('211221_dipoles_SF_rev_steps/results/%s/line_x_y4cm25.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)

            plt.plot(df_DC_center['X'], df_DC_center['BY'], label='y=z=0')
            #plt.plot(df_DC_shiftZ['X'], df_DC_shiftZ['BY'], label='y=0, z=42.5mm')
            plt.plot(df_DC_shiftY['X'], df_DC_shiftY['BY'], label='y=42.5mm, z=0')
            plt.legend()

            diff_list = []

            for i in range (1150, 1400):
                diff = abs(df_DC_center['BY'][i] - df_DC_shiftY['BY'][i])  
                diff_list.append(diff)
        
            minimum = np.min(diff_list)
            value = diff_list.index(minimum)
            
            
            value_x = df_DC_center['X'][value+1150]
            
            BY_value = df_DC_center['BY'][value+1150]
            
            arg = np.argmin(np.abs(df_DC_center['BY'][1500:2000] - BY_value))
            
            second = df_DC_center['X'][arg+1500]
            
            sepy.append(second - value_x)
            
            print ("Intersect at: " + str(value_x))
            crosses.append(value_x)
            
    
            
        else:
            continue   
            
print (crosses[0])
print (crosses[1])
print (crosses[2])
print (crosses[3])
print (crosses[4])
print (crosses[5])

print()

print (sepy[0])
print (sepy[1])
print (sepy[2])
print (sepy[3])
print (sepy[4])
print (sepy[5])
# Out:
# X_5_5_30_60_90_100_Y1_65_T1_5_T2_0_I_300
# Intersect at: 4.48
# X_5_5_30_60_90_100_Y1_65_T1_10_T2_0_I_300
# Intersect at: 4.68
# X_5_5_30_60_90_100_Y1_65_T1_20_T2_0_I_300
# Intersect at: 5.44
# X_5_5_30_60_90_100_Y1_65_T1_30_T2_0_I_300
# Intersect at: 5.9
# X_5_5_30_60_90_100_Y1_65_T1_40_T2_0_I_300
# Intersect at: 6.94
# X_5_5_30_60_90_100_Y1_65_T1_50_T2_0_I_300
# Intersect at: 7.98
# 4.48
# 4.68
# 5.44
# 5.9
# 6.94
# 7.98
#
# 13.14
# 12.719999999999999
# 11.619999999999997
# 10.78
# 9.139999999999997
# 7.279999999999999

# %%
targetdir = 'XA_0.5_YA_6.5_LA_1.5_LB_10_LC_1_TZ_10_I_350'

df_DC_center = pd.read_csv('211219_dipoles_SF_reverse/results/%s/line_x.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)
df_DC_shiftZ = pd.read_csv('211219_dipoles_SF_reverse/results/%s/line_x_z4cm25.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)
df_DC_shiftY = pd.read_csv('211219_dipoles_SF_reverse/results/%s/line_x_y4cm25.table' %targetdir, names=['X','Y','Z','BX','BY','BZ','Phi'], sep='\s+', skiprows=9)

#plt.plot(df_DC_center['X'], df_DC_center['BY'], label='y=z=0')
#plt.plot(df_DC_shiftZ['X'], df_DC_shiftZ['BY'], label='y=0, z=42.5mm')
#plt.plot(df_DC_shiftY['X'], df_DC_shiftY['BY'], label='y=42.5mm, z=0')
#plt.legend()

Field_max = df_DC_center['BY'][750:1250].max()
Field_min = df_DC_center['BY'][0:500].min()

step = Field_max/5000
start = Field_min/step
#print (start)


dist1 = []
dist2 = []
dist3 = []
dist_min = []
Field_list = []

for p in range (int(start), 1000):
    
    Field = p*step 
    Field_list.append(Field)
    
    arg1 = np.argmin(np.abs(df_DC_center['BY'][0:250] - Field))    
    arg2 = np.argmin(np.abs(df_DC_center['BY'][250:1000] - Field)) + 250
    arg3 = np.argmin(np.abs(df_DC_center['BY'][1000:1750] - Field)) + 1000 
    arg4 = np.argmin(np.abs(df_DC_center['BY'][1750:2000] - Field))+ 1750

    diff1 = df_DC_center['X'][arg2] - df_DC_center['X'][arg1]
    diff2 = df_DC_center['X'][arg3] - df_DC_center['X'][arg2]
    diff3 = df_DC_center['X'][arg4] - df_DC_center['X'][arg3]
    

    
    
    dist1.append(diff1)
    dist2.append(diff2)
    dist3.append(diff3)
    dist_min.append(min(diff1, diff2, diff3))


plt.plot(Field_list, dist1)
plt.plot(Field_list, dist2)
plt.plot(Field_list, dist3)
#plt.plot(Field_list, dist_min)
Field_list[np.argmax(np.array(dist_min))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\DGEORG~1\AppData\Local\Temp/ipykernel_5844/1358086923.py in <module>
#      51 plt.plot(Field_list, dist3)
#      52 #plt.plot(Field_list, dist_min)
# ---> 53 Field_list[np.argmax(np.array(dist_min))]
#
# <__array_function__ internals> in argmax(*args, **kwargs)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\core\fromnumeric.py in argmax(a, axis, out)
#    1193
#    1194     """
# -> 1195     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#    1196
#    1197
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
# ...

# %%
def intersect(Field):

    arg1 = np.argmin(np.abs(df_DC_center['BY'][0:250] - Field))  
    arg2 = np.argmin(np.abs(df_DC_center['BY'][250:1000] - Field)) + 250
    arg3 = np.argmin(np.abs(df_DC_center['BY'][1000:1750] - Field)) + 1000
    arg4 = np.argmin(np.abs(df_DC_center['BY'][1750:2000] - Field)) + 1750

    diff1 = df_DC_center['X'][arg2] - df_DC_center['X'][arg1]
    diff2 = df_DC_center['X'][arg3] - df_DC_center['X'][arg2]
    diff3 = df_DC_center['X'][arg4] - df_DC_center['X'][arg3]
    

print(df_DC_center['BY'][arg1])
print(df_DC_center['BY'][arg2])
print(df_DC_center['BY'][arg3])
print(df_DC_center['BY'][arg4])

print(df_DC_center['X'][arg1])
print(df_DC_center['X'][arg2])
print(df_DC_center['X'][arg3])
print(df_DC_center['X'][arg4])

dist1.append(diff1)
dist2.append(diff2)
dist3.append(diff3)

#plt.plot(BY_list, dist1)
# Out:
# 21.9460645731
# 22.0616819659
# 22.0609897328
# 22.0964662116
# -20.0
# -0.34
# 0.3
# 18.74

# %%
np.argmin((np.abs(df_DC_center['BY'][250:1000] - Field)))
# Out:
# 731

# %%
df_DC_center['X' == 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DGEORG~1\AppData\Local\Temp/ipykernel_5844/1373473850.py in <module>
# ----> 1 df_DC_center['X' == 0]
#
# NameError: name 'df_DC_center' is not defined

# %%
df_DC_center['BY'][250:1000]
# Out:
# 250     5.546998
# 251     5.539626
# 252     5.532255
# 253     5.524883
# 254     5.517511
#          ...
# 995    21.732795
# 996    21.733686
# 997    21.734577
# 998    21.735469
# 999    21.736360
# Name: BY, Length: 750, dtype: float64
